# %% [markdown]
# # Using the Atom Text Editor
#
# There are many occassions in which you may want a generic text editor. For that purpose, I would recommend [Atom (downloadable here)](https://atom.io/). It is free, and extremely powerful.
#
# To make Atom accessible from the command line (so you can type things like `atom FILENAME` and have the file you named open in Atom), make sure that after you install Atom, you:
#
#
# **Atom on a Mac:**
#
# Go to `Atom` and select "Install Shell Commands":
#
# ![atom_shell_install](images/atom_mac.png)

# %% [markdown]
# **Atom on Windows:**
#
# Download the Atom installer, and select "Yes, Always" to the prompt "Register as default atom:// URI handler?"!
