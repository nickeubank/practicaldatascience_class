# %% [markdown]
# ## Question 1
#
# We load the data from github
#
# Here's example code I want to type but note run:
#
# ```
# import pandas as pd
#
# ```
#
# $y = x*\beta + \epsilon$

# %%
import pandas as pd
import numpy as np
# Download the data
acs = pd.read_stata("https://github.com/nickeubank/MIDS_Data/raw/master/US_AmericanCommunitySurvey/US_ACS_2017_10pct_sample.dta")

# %%
acs.head()
# Out:
#    year  datanum   serial      cbserial          numprec subsamp  hhwt  \
# 0  2017        1   177686  2.017001e+12                9      64    55
# 1  2017        1  1200045  2.017001e+12                6      79    25
# 2  2017        1    70831  2.017000e+12  1 person record      36    57
# 3  2017        1   557128  2.017001e+12                2      10    98
# 4  2017        1   614890  2.017001e+12                4      96    54
#
#                                    hhtype       cluster    adjust  ...  \
# 0  female householder, no husband present  2.017002e+12  1.011189  ...
# 1       male householder, no wife present  2.017012e+12  1.011189  ...
# 2          male householder, living alone  2.017001e+12  1.011189  ...
# 3         married-couple family household  2.017006e+12  1.011189  ...
# 4         married-couple family household  2.017006e+12  1.011189  ...
#
#    migcounty1                 migmet131 vetdisab                   diffrem  \
# ...

# %%
with_index = acs.set_index('sex')
with_index.head()
# Out:
#         year  datanum   serial      cbserial          numprec subsamp  hhwt  \
# sex
# female  2017        1   177686  2.017001e+12                9      64    55
# female  2017        1  1200045  2.017001e+12                6      79    25
# boy     2017        1    70831  2.017000e+12  1 person record      36    57
# female  2017        1   557128  2.017001e+12                2      10    98
# boy     2017        1   614890  2.017001e+12                4      96    54
#
#                                         hhtype       cluster    adjust  ...  \
# sex                                                                     ...
# female  female householder, no husband present  2.017002e+12  1.011189  ...
# female       male householder, no wife present  2.017012e+12  1.011189  ...
# boy             male householder, living alone  2.017001e+12  1.011189  ...
# female         married-couple family household  2.017006e+12  1.011189  ...
# ...

# %%
acs['sex'] = acs.sex.replace("male", "boy")

# %%
acs.sex.dtype
# Out:
# CategoricalDtype(categories=['boy', 'female'], ordered=True)

# %%
# Below is age
acs.age
# Out:
# 0          4
# 1         17
# 2         63
# 3         66
# 4          1
#           ..
# 318999    33
# 319000     4
# 319001    20
# 319002    47
# 319003    33
# Name: age, Length: 319004, dtype: category
# Categories (97, object): ['less than 1 year old' < '1' < '2' < '3' ... '93' < '94' < '95' < '96']

# %%
acs.age.replace('90 (90+ year olds)', "91")
