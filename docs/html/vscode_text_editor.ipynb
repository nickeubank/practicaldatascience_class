# %% [markdown]
# # Using the VSCode Text Editor
#
# There are many occassions in which you may want a generic text editor. For that purpose, I would recommend [VSCode (downloadable here)](https://code.visualstudio.com/). It is free, and extremely powerful.
#
# To make VS Code accessible from the command line (so you can type things like `code FILENAME` and have the file you named open in VS Code), make sure that after you install VSCode, follow the directions [here (for macs)](https://code.visualstudio.com/docs/setup/mac#_launching-from-the-command-line).
