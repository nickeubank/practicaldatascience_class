# %% [markdown]
# # Solutions

# %% [markdown]
# - [Numpy Vector Solutions](exercises/Solutions_numpy_vectors.ipynb)
# - [Numpy View/Copies Solutions](exercises/Solutions_numpy_viewcopies.ipynb)
# - [Pandas Series](exercises/Solutions_series.ipynb)
# - [Pandas DataFrames](exercises/Solutions_dataframes.ipynb)
# - [Missing Data](exercises/Solutions_missing.ipynb)
# - [Data Cleaning](exercises/Solutions_cleaning.ipynb)
# - [Merging](exercises/Solutions_merging.ipynb)
# - [Plotting Part 1](exercises/Solutions_plotting_part1.ipynb)
