# %% [markdown]
# # Code-Drawing Template

# %% [markdown]
# ![code frame](../images/code_frame.png)
# ![code frame](../images/code_frame.png)
# ![code frame](../images/code_frame.png)
# ![code frame](../images/code_frame.png)
# ![code frame](../images/code_frame.png)
# ![code frame](../images/code_frame.png)
# ![code frame](../images/code_frame.png)
# ![code frame](../images/code_frame.png)
# ![code frame](../images/code_frame.png)
# ![code frame](../images/code_frame.png)
# ![code frame](../images/code_frame.png)
# ![code frame](../images/code_frame.png)
